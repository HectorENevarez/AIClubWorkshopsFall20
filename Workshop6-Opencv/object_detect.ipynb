# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorENevarez/AIClubWorkshops/blob/master/Workshop6-Opencv/object_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Loading in imports
from google.colab.patches import cv2_imshow
import imutils
import cv2

# %%
#Loading in image
image = cv2.imread('tetris_blocks.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FB728A3C8>

# %%
#Converting to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=482x250 at 0x7F6FB69E02B0>

# %%
#Edge detection
edged = cv2.Canny(gray, 30, 150)
cv2_imshow(edged)
# Out:
# <PIL.Image.Image image mode=L size=482x250 at 0x7F6FB69E0EF0>

# %%
#Thresholding
thresh = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)[1]
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=482x250 at 0x7F6FB6995860>

# %%
#Detecting and drawing contours
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
output = image.copy()

for c in cnts:
  cv2.drawContours(output, [c], -1, (0, 0, 0), 3)
  cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19160>
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19898>
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19080>
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19828>
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19A20>
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED19390>

# %%
#Adding text
text = "I found {} objects".format(len(cnts))
cv2.putText(output, text, (10,25), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F6FAED191D0>

# %% [markdown]
# This workshop was created by Adrian Rosebrock<br>
# you can find the entire workshop [here](https://www.pyimagesearch.com/2018/07/19/opencv-tutorial-a-guide-to-learn-opencv/)
