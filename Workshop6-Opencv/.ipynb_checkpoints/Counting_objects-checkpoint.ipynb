# %%
#Simple script to count the amount of tetris objects in the image
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Tetromino.png')
plt.imshow(image)
plt.show()

# %%
#Converting to greyscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("yes",gray)
